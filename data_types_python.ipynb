# %% [markdown]
# # data types in python
# 1. different vatype of values assigned to variables
# 2. basically 3 data types in python
# 3. int(intger) - numerical values like 1,2,3.....n
# 4. str(string) - characters examples "abcd","ghjk","qwerty"
# 5. float(decimals) - numerical with decimals - 10,25,100,125,225.....

# %%
name = "KEREN"
age = 16
salary = 12000000000
data = "07/01/2009"
print (name)
print (age)
print (salary)
print (data)
print (type(name))
print (type(age))
print (type(salary))
print (type(data))
# Out:
# KEREN
# 16
# 12000000000
# 07/01/2009
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>

# %%
# concatenations
a=100
b=200
print(a+b)
# Out:
# 300

# %%
n1 = "python"
n2=" programming"
print (n1+n2)
# Out:
# python programming

# %%
a=100
b= "300"
print(a+int(b))
# Out:
# 400
