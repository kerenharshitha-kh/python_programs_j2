# %% [markdown]
# # conditional statements in python
# 1. Python has four types of conditional statements
# 2. 'if' statement
# 3. 'elif' statement
# 4. 'else' statement
# 5. 'nested' statement
#
# ```python -  if
# if(condition): # if condition True inside statements are running
#     statement1
#     statements......
# ```
#
# ```python - if,else
# if(condition) #if condition True inside statements are running
#   statement1
#   statement2....n
# else #if condition Fails its went to else statement and print inside statements
#   statement1
#   statement2.....n
#
# ``` python - if,elif,else
#
# if(condition):
#     statements
# elif(condition):
#     statements
# else(condition):
# statements
#
# ```

# %%
#Write a program to find the given number is a even  number?
number = int(input("enter number here:"))
if(number%2==0):
    print(number,"is a even number")
# Out:
# enter number here: 76
# 76 is a even number

# %%
1020%2
# Out:
# 0

# %%
# write a program to find the given number is even or odd number?
num  = int(input("please enter number here:"))
if (num%2 == 1):
    print(num,"is odd number")
else:
    print(num,"is even number")
# Out:
# please enter number here: 9
# 9 is odd number

# %%
# write a program to find the given number is given positive or negative or zero
n = int(input("please enter number here:"))
if( n>0):
  print( n,"is a positive number")
elif ( n<0):
    print(n,"is a negative number")
else:
    print (n,"is zero")
# Out:
# please enter number here: 0000
# 0 is zero

# %%
# write a program to find the largest number from three numbers
v1 = int(input("please enter first no."))
v2 = int(input("please enter second no."))
v3 = int(input("please enter third no."))
if (v1>=v2 and v1>=v3):
     print ( v1," IS THE LARGEST NO.")
elif ( v2>=v1 and v2>=v3):
     print (v2,"is the Largest No.")
else:
    print(v3,"is the largest no.")
# Out:
# please enter first no. -45
# please enter second no. -76
# please enter third no. -10000000000008
# -45  IS THE LARGEST NO.

# %%
"""
Write a program to find the grades based on students marks
1. if marks in between 80 to 100 - A grade
2. if marks in between 60-79 - B grade
3. if marks are in between 40 to 59 - C grade 
4. if marks are in between 25 to 39 - D grade
5. if marks in between 0 to 24  - FAIL
6. if other than above marks output is - Please enter correct marks

"""

marks = int(input("Enter student marks here:"))
if (marks>=80 and marks <=100):
   print(marks,"A GRADE")
elif (marks >=60 and marks <=79):
   print (marks,"B grade")
elif ( marks>=40 and marks <=59):
   print(marks, "C Grade")
elif (marks>=25 and marks <=39):
  print (marks,"D grade")
elif(marks>=0 and marks<=24):
  print (marks,"FAIL")
else:
  print ("PLEASE ENTER CORRECT MARKS")
# Out:
# Enter student marks here: -65
# PLEASE ENTER CORRECT MARKS

# %%
# write a program to valid login credentials using conditional statements
username= str(input("please enter username"))
if (username == "Keren@07"):
    print("username is valid")
    password = str(input("please enter password here"))
    if (password == "KEREN@2009"):
        print("user credentials succesfully valid")
    else:
        print(" password is invalid")
else:
    print("username is invalid")
# Out:
# please enter username Keren@07
# username is valid
